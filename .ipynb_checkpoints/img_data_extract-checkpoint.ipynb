# %%
import os
from PIL import Image 

print(os.getcwd())

folder_images = "downloads"
size_images = dict()

for dirpath, _, filenames in os.walk(folder_images):
    for path_image in filenames:
        image = os.path.abspath(os.path.join(dirpath, path_image))
        with Image.open(image) as img:
            width, heigth = img.size
            size_images[path_image] = {'width': width, 'heigth': heigth}

print(size_images)
# Out:
# /home/dragos/projects/document_vs_logo_img_classification
# {'44.d5f5ab14809fb5b39c88cab57805c03f32546b01.png': {'width': 805, 'heigth': 608}, '68.ViewInvoice.png': {'width': 800, 'heigth': 553}, '52.Sample_invoice.png': {'width': 565, 'heigth': 724}, '67.invoices.png': {'width': 558, 'heigth': 294}, '65.what-is-invoice-398303_color2-5c9292c846e0fb0001442783.png': {'width': 735, 'heigth': 490}, '56.Invoice-details.png': {'width': 831, 'heigth': 520}, '75.LARGE_635747981557862333@eninvoice.png': {'width': 690, 'heigth': 973}, '74.ce5d530-UpdateBillingAddress.png': {'width': 791, 'heigth': 716}, '23.invoice-main.png': {'width': 586, 'heigth': 492}, '59.Business-invoice.png': {'width': 778, 'heigth': 715}, '26.Terms%20on%20previewed%20invoice.png': {'width': 800, 'heigth': 457}, '28.Picture4.png': {'width': 623, 'heigth': 712}, '79.create-invoices.png': {'width': 620, 'heigth': 503}, '50.charge_card1.png': {'width': 1007, 'heigth': 743}, '8.new-invoice-layout.png': {'width': 908, 'heigth': 697}, '58.Invoice-Number-Templates-2.png': {'width': 692, 'heigth': 653}, '72.invoice.png': {'width': 759, 'heigth': 760}, '32.340px-Services-Rendered-Invoice.png': {'width': 340, 'heigth': 440}, '57.invoice-software-features-online-invoicing-1x.png': {'width': 789, 'heigth': 566}, '25.2.en-02276cbfcad84d1c71971c8cce23e8a86359172cc84c002a6fc438b5e63d1517.png': {'width': 912, 'heigth': 396}, '37.pdf.png': {'width': 800, 'heigth': 500}, '20.invoice.png': {'width': 640, 'heigth': 522}, '5.word-Word-Invoice2-1.png': {'width': 423, 'heigth': 548}, '3.pdf-PDF-Invoice3-1.png': {'width': 478, 'heigth': 620}, '41.invoice_module_screenshot.png': {'width': 723, 'heigth': 699}, '27.How_To_Get_A_Copy_Of_Your_Adafruit_Invoice_-_YouTube.png': {'width': 640, 'heigth': 480}, '15.invoice-hero-full-it.png': {'width': 407, 'heigth': 525}, '18.screenshot_invoiceberry_invoice_template_2.png': {'width': 600, 'heigth': 776}, '34.attachment-in-invoice-email-callout.png': {'width': 482, 'heigth': 418}, '49.proforma-invoice-template-1.png': {'width': 400, 'heigth': 518}, '83.edi_invoice_structure.png': {'width': 870, 'heigth': 397}, '77.HO-Advertising-Billing.png': {'width': 958, 'heigth': 361}, '16.invoice.png': {'width': 690, 'heigth': 702}, '66.pro_1.png': {'width': 375, 'heigth': 485}, '76.sales-invoice-template.png': {'width': 578, 'heigth': 747}, '42.advance-invoices1.png': {'width': 1480, 'heigth': 521}, '39.file-TpdeA5qCpF.png': {'width': 737, 'heigth': 816}, '45.sample-invoice-uk-372x523.png': {'width': 372, 'heigth': 523}, '60.invoicing-tracking.png': {'width': 600, 'heigth': 610}, '81.425x575_2083315001395045.png': {'width': 425, 'heigth': 575}, '36.2996bdf0eb9e70ffdfe7.png': {'width': 498, 'heigth': 1057}, '11.invoice-gen-og-img.png': {'width': 1200, 'heigth': 630}, '78.Invoice-Journal.png': {'width': 995, 'heigth': 469}, '69.orange-standard-invoice-template.png': {'width': 550, 'heigth': 676}, '82.Billing_per_print_str.png': {'width': 746, 'heigth': 516}, '9.proforma-invoice-template.png': {'width': 748, 'heigth': 951}, '61.print-email-invoice-view-billing.png': {'width': 708, 'heigth': 765}, '30.invoice.png': {'width': 753, 'heigth': 649}, '35.file-flvS8wPDcg.png': {'width': 786, 'heigth': 461}, '46.quoting_invoicing_demo_screen_2.png': {'width': 990, 'heigth': 606}, '19.template-header-image-1x.png': {'width': 856, 'heigth': 713}, '1.blank-Excel-Invoice2-1.png': {'width': 355, 'heigth': 497}, '55.pic_170.png': {'width': 600, 'heigth': 850}, '47.Screen_Shot_2018-04-13_at_12_48_06_PM.png': {'width': 568, 'heigth': 787}, '51.KB-Inv-IR-CPI-01-Final.png': {'width': 764, 'heigth': 866}, '40.invoicehome-espanol-informesydeclaraciones-1.png': {'width': 564, 'heigth': 439}, '6.Jobber-invoice-example-0x0_c.png': {'width': 743, 'heigth': 958}, '29.2018-09_panel_billing_view_invoice_02.png': {'width': 580, 'heigth': 729}, '43.invoicing-software-that-helps-you-get-paid.png': {'width': 577, 'heigth': 473}, '48.invoice-hero-generic.png': {'width': 566, 'heigth': 584}, '63.contact.png': {'width': 1188, 'heigth': 474}, '84.Working% ...

# %%
import os

filenames= os.listdir (".") # get all files' and folders' names in the current directory

result = []
for filename in filenames: # loop through all the files and folders
    if os.path.isdir(os.path.join(os.path.abspath("."), filename)): # check whether the current object is a folder or not
        result.append(filename)
        
result.sort()

f= open('list.txt','w')
for index,filename in enumerate(result):
    f.write("%s. %s \n"%(index,filename))

f.close()

# %%
import os

folder_images = "downloads\."
filenames= os.listdir (folder_images) # get all files' and folders' names in the current directory

result = []
for filename in filenames: # loop through all the files and folders
    if os.path.isdir(os.path.join(os.path.abspath("."), filename)): # check whether the current object is a folder or not
        result.append(filename)
        
result.sort()

f= open('list.txt','w')
for index,filename in enumerate(result):
    f.write("%s. %s \n"%(index,filename))

f.close()
